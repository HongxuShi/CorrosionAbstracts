# %%
import numpy as np
import pandas as pd
data=pd.read_csv('DATA.csv')
#data.head()
correlationmatrix=data[['MWL','LC','LD','ASL','JD','HD','NCC']].corr()
print(correlationmatrix)
# Out:
#           MWL        LC        LD       ASL        JD        HD       NCC
# MWL  1.000000  0.502981  0.110204 -0.030188  0.326234  0.049815  0.121829
# LC   0.502981  1.000000 -0.039763  0.027645  0.490105  0.138882  0.043921
# LD   0.110204 -0.039763  1.000000 -0.241036  0.028817 -0.189098  0.151503
# ASL -0.030188  0.027645 -0.241036  1.000000 -0.064429  0.021046 -0.091764
# JD   0.326234  0.490105  0.028817 -0.064429  1.000000 -0.022948  0.141875
# HD   0.049815  0.138882 -0.189098  0.021046 -0.022948  1.000000 -0.013209
# NCC  0.121829  0.043921  0.151503 -0.091764  0.141875 -0.013209  1.000000
